# %% [markdown]
# # TUGAS 3 - Visualisasi Data #
#
# Nama : Tritia Mutiara
#
# Nim : 191402048

# %% [markdown]
# Membuat visualisasi data diluar dari materi yang diberikan menggunakan CSV atau Excel file

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('mental-heath-care.csv')

# %%
# Membaca file dari excel/csv
data.head()
# Out:
#                                            Indicator              Group  \
# 0  Took Prescription Medication for Mental Health...  National Estimate
# 1  Took Prescription Medication for Mental Health...             By Age
# 2  Took Prescription Medication for Mental Health...             By Age
# 3  Took Prescription Medication for Mental Health...             By Age
# 4  Took Prescription Medication for Mental Health...             By Age
#
#            State       Subgroup Phase  Time Period      Time Period Label  \
# 0  United States  United States     2           13  Aug 19 - Aug 31, 2020
# 1  United States  18 - 29 years     2           13  Aug 19 - Aug 31, 2020
# 2  United States  30 - 39 years     2           13  Aug 19 - Aug 31, 2020
# 3  United States  40 - 49 years     2           13  Aug 19 - Aug 31, 2020
# 4  United States  50 - 59 years     2           13  Aug 19 - Aug 31, 2020
#
#   Time Period Start Date Time Period End Date  Value  LowCI  HighCI  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8276 entries, 0 to 8275
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Indicator               8276 non-null   object
#  1   Group                   8276 non-null   object
#  2   State                   8276 non-null   object
#  3   Subgroup                8276 non-null   object
#  4   Phase                   8276 non-null   object
#  5   Time Period             8276 non-null   int64
#  6   Time Period Label       8276 non-null   object
#  7   Time Period Start Date  8276 non-null   object
#  8   Time Period End Date    8276 non-null   object
#  9   Value                   7996 non-null   float64
#  10  LowCI                   7996 non-null   float64
#  11  HighCI                  7996 non-null   float64
#  12  Confidence Interval     7996 non-null   object
#  13  Quartile Range          5508 non-null   object
# ...

# %%
data.values
# Out:
# array([['Took Prescription Medication for Mental Health, Last 4 Weeks',
#         'National Estimate', 'United States', ..., '19.0 - 19.8', nan,
#         nan],
#        ['Took Prescription Medication for Mental Health, Last 4 Weeks',
#         'By Age', 'United States', ..., '17.2 - 20.3', nan, nan],
#        ['Took Prescription Medication for Mental Health, Last 4 Weeks',
#         'By Age', 'United States', ..., '17.3 - 19.2', nan, nan],
#        ...,
#        ['Needed Counseling or Therapy But Did Not Get It, Last 4 Weeks',
#         'By State', 'West Virginia', ..., '7.8 - 14.6', '9.3-10.9', nan],
#        ['Needed Counseling or Therapy But Did Not Get It, Last 4 Weeks',
#         'By State', 'Wisconsin', ..., '4.1 - 8.2', '5.9-9.2', nan],
#        ['Needed Counseling or Therapy But Did Not Get It, Last 4 Weeks',
#         'By State', 'Wyoming', ..., '5.3 - 11.7', '5.9-9.2', nan]],
#       dtype=object)

# %%
data[["Indicator", "Subgroup" , "Confidence Interval"]].head(3)
# Out:
#                                            Indicator       Subgroup  \
# 0  Took Prescription Medication for Mental Health...  United States
# 1  Took Prescription Medication for Mental Health...  18 - 29 years
# 2  Took Prescription Medication for Mental Health...  30 - 39 years
#
#   Confidence Interval
# 0         19.0 - 19.8
# 1         17.2 - 20.3
# 2         17.3 - 19.2

# %%
y = np.array([9,4,5,6])
mylabels = ["18", "30", "40", "50"]
myexplode =[0,0,0,0.5]
plt.pie(y, labels= mylabels, explode = myexplode, shadow= True)
plt.show()

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib as plt
sns.set(style="white", color_codes=True)

# %%
data= pd.read_csv("mental-heath-care.csv")

# %%
sns.boxplot(x="Indicator" , y="Value", data=data)
# Out:
# <AxesSubplot:xlabel='Indicator', ylabel='Value'>

# %%
sns.violinplot(x="Quartile Range", y="LowCI", data=data, size=20)
# Out:
# <AxesSubplot:xlabel='Quartile Range', ylabel='LowCI'>
